# %% [markdown]
# <a href="https://colab.research.google.com/github/don05050505/don05050505/blob/main/MNIST_ANN_%ED%95%99%EC%8A%B5_%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras import datasets
from keras.utils import np_utils

# %%
# def Data_func():
    # (X_train, y_train), (X_test, y_test) = datasets.mnist.load_data()
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
L, W, H = X_train.shape
X_train = X_train.reshape(-1, W*H)
X_test = X_test.reshape(-1, W*H)
Y_train = np_utils.to_categorical(y_train)
Y_test = np_utils.to_categorical(y_test)
y_test = y_test[:len(X_test)]
y_test = y_test.reshape(-1, 10)



X_train = X_train / 255.0
X_test = X_test / 255.0


Nin = 784
Nh = 100
number_of_class = 10
Nout = number_of_class

model = ANN_seq_class(Nin, Nh, Nout)
(X_train, y_train), (X_test, y_test)#
history = model.fit(X_train, Y_train, epochs=5, batch_size=100, validation_split=0.2)
performance_test = model.evaluate(X_test, y_test, batch_size=100)
print('Test Loss & Accuracy -->', performance_test)

plot_loss(history)
plot.show()
plot_acc(history)
plt.show()

if __name__ == '__main__':
    main()

# %%
# def main():
Nin = 784
Nh = 100
number_of_class = 10
Nout = number_of_class

model = ANN_seq_class(Nin, Nh, Nout)
(X_train, y_train), (X_test, y_test)#
history = model.fit(X_train, Y_train, epochs=5, batch_size=100, validation_split=0.2)
performance_test = model.evaluate(X_test, y_test, batch_size=100)
print('Test Loss & Accuracy -->', performance_test)

plot_loss(history)
plot.show()
plot_acc(history)
plt.show()

if __name__ == '__main__':
    main()

# %%
# import matplotlib.pyplot as plt

# def plot_loss(history):
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc=0)

# def plot_acc(history):
plt,plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc=0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Define the ANN_seq_class function (placeholder)
def ANN_seq_class(input_size, hidden_size, output_size):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(input_size,)),
        tf.keras.layers.Dense(hidden_size, activation='relu'),
        tf.keras.layers.Dense(output_size, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Define plot_loss and plot_acc functions (placeholders)
def plot_loss(history):
    # Plot loss history
    pass

def plot_acc(history):
    # Plot accuracy history
    pass

def main():
    (X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
    L, W, H = X_train.shape
    X_train = X_train.reshape(-1, W * H)
    X_test = X_test.reshape(-1, W * H)
    Y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    Y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)
    y_test = y_test[:len(X_test)]
    y_test = y_test.reshape(-1, 10)

    X_train = X_train / 255.0
    X_test = X_test / 255.0

    Nin = 784
    Nh = 100
    number_of_class = 10
    Nout = number_of_class

    model = ANN_seq_class(Nin, Nh, Nout)
    history = model.fit(X_train, Y_train, epochs=5, batch_size=100, validation_split=0.2)
    performance_test = model.evaluate(X_test, Y_test, batch_size=100)
    print('Test Loss & Accuracy -->', performance_test)

    plot_loss(history)
    plt.show()
    plot_acc(history)
    plt.show()

if __name__ == '__main__':
    main()

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Define the ANN_seq_class function (placeholder)
def ANN_seq_class(input_size, hidden_size, output_size):
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(input_size,)),
        tf.keras.layers.Dense(hidden_size, activation='relu'),
        tf.keras.layers.Dense(output_size, activation='softmax')
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

def plot_loss(history):
    plt.figure(figsize=(5, 3))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()
    plt.show()

def plot_acc(history):
    plt.figure(figsize=(5, 3))
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Accuracy Over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid()
    plt.show()

def main():
    (X_train, y_train), (X_test, y_test) = tf.keras.datasets.mnist.load_data()
    L, W, H = X_train.shape
    X_train = X_train.reshape(-1, W * H)
    X_test = X_test.reshape(-1, W * H)
    Y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
    Y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)
    y_test = y_test[:len(X_test)]
    y_test = y_test.reshape(-1, 10)

    X_train = X_train / 255.0
    X_test = X_test / 255.0

    Nin = 784
    Nh = 100
    number_of_class = 10
    Nout = number_of_class

    model = ANN_seq_class(Nin, Nh, Nout)
    history = model.fit(X_train, Y_train, epochs=5, batch_size=100, validation_split=0.2)
    performance_test = model.evaluate(X_test, Y_test, batch_size=100)
    print('Test Loss & Accuracy -->', performance_test)

    plot_loss(history)
    plot_acc(history)

if __name__ == '__main__':
    main()
